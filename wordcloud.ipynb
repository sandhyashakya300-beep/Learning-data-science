# %%
# %pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('NetFlix.csv')

# %%
print(data.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %%
#Selecting specific director 
director_name = "Les Mayfield"
director_data = data[data['director'].str.contains(director_name,case=False,na=False)]

# Join all the description into a single string
all_plots = ''.join(director_data['description'].dropna())

#create a wordcloud for the director plot
wordcloud=WordCloud(width=700,height=400,background_color='skyblue').generate(all_plots)
plt.figure(figsize=(10,4))
plt.imshow(wordcloud,interpolation='bilinear')
plt.title(f"Most Common Keywords In Movies{director_name}")
plt.axis('off')
plt.show()

# %%
# Selecting specific director
director_name = "Les Mayfield"
# Added na=False to handle missing data safely
director_data = data[data['director'].str.contains(director_name, case=False, na=False)]

    # Join all the descriptions into a single string
all_plots = ' '.join(director_data['cast'].dropna()) # added .dropna() just in case Plots are missing too

 # create a wordcloud for the director plot (fixed background_color typo)
wordcloud = WordCloud(width=700, height=400, background_color='skyblue').generate(all_plots)
    
plt.figure(figsize=(10,4))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title(f"Most Common Keywords In Movies by {director_name}")
plt.axis('off')
plt.show()

# %%
#Selecting specific director 
director_name = "Vikram Bhatt"
director_data = data[data['director'].str.contains(director_name,case=False,na=False)]

# Join all the description into a single string
all_plots = ''.join(director_data['genres'].dropna())

#create a wordcloud for the director plot
wordcloud=WordCloud(width=700,height=400,background_color='skyblue').generate(all_plots)
plt.figure(figsize=(10,4))
plt.imshow(wordcloud,interpolation='bilinear')
plt.title(f"Most Common Keywords In Movies{director_name}")
plt.axis('off')
plt.show()
